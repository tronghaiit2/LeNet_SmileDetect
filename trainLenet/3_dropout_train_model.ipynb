# %%
data_set = "dataset/SMILEsmileD/SMILEs"
output = "output"
# initialize the list of data and labels
data = []
labels = []

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical
from pipeline.nn.conv import LeNet
from imutils import paths
from matplotlib import pyplot
import imutils 
import numpy as np
import argparse
import cv2
import os

# %%
# loop over the input images
for imagePath in sorted(list(paths.list_images(data_set))):
    # load the image, pre-process it, and store it in the data list
    #print(imagePath)
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #image = imutils.resize(image, width=32)
    image = cv2.resize(image, (32,32), interpolation=cv2.INTER_AREA)
    image = img_to_array(image)
    data.append(image)

    # extract the class label from the image path and update the label list
    label = imagePath.split(os.path.sep)[-3]
    label = "smiling" if label == "positives" else "not_smiling"
    labels.append(label)

count = 0
count_neg = 0
for i in range(len(labels)):
    if labels[i] == "smiling":
        count += 1
    else:
        count_neg += 1

print(count)
print(count_neg)
# Out:
# 6500
# 6500

# %%
len(labels)
#labels
# Out:
# 13000

# %%
# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
labels
# Out:
# array(['not_smiling', 'not_smiling', 'not_smiling', ..., 'smiling',
#        'smiling', 'smiling'], dtype='<U11')

# %%
# convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
labels = to_categorical(le.transform(labels), 2)

# account for skew in the labeled data
classTotals = labels.sum(axis=0)
classWeight = classTotals.max() / classTotals

# %%
classTotals
# Out:
# array([6500., 6500.], dtype=float32)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=42)

# %%
print(len(trainX), len(trainY), len(testX), len(testY))
# Out:
# 10400 10400 2600 2600

# %%
# initialize the model
print("[INFO] compiling model...")
model = LeNet.build(width=32, height=32, depth=1, classes=2)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
# train the network
# Dropout = 0.2
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 8s 45ms/step - loss: 0.5687 - accuracy: 0.6948 - val_loss: 0.4681 - val_accuracy: 0.7862
# Epoch 2/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.4451 - accuracy: 0.7997 - val_loss: 0.4046 - val_accuracy: 0.8138
# Epoch 3/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3948 - accuracy: 0.8218 - val_loss: 0.3618 - val_accuracy: 0.8412
# Epoch 4/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3588 - accuracy: 0.8421 - val_loss: 0.3520 - val_accuracy: 0.8473
# Epoch 5/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3344 - accuracy: 0.8554 - val_loss: 0.3262 - val_accuracy: 0.8650
# Epoch 6/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3137 - accuracy: 0.8653 - val_loss: 0.3269 - val_accuracy: 0.8608
# Epoch 7/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3047 - accuracy: 0.8689 - val_loss: 0.3032 - val_accuracy: 0.8681
# Epoch 8/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2898 - accuracy: 0.8799 - val_loss: 0.2798 - val_accuracy: 0.8827
# Epoch 9/20
# 163/163 [==============================] - 8s 47ms/step - loss: 0.2763 - accuracy: 0.8838 - val_loss: 0.2781 - val_accuracy: 0.8865
# Epoch 10/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2702 - accuracy: 0.8906 - val_loss: 0.2694 - val_accuracy: 0.8919
# Epoch 11/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2656 - accuracy: 0.8898 - val_loss: 0.2836 - val_accuracy: 0.8877
# Epoch 12/20
# 163/163 [==============================] - 8s 50ms/step - loss: 0.2536 - accuracy: 0.8956 - val_loss: 0.2683 - val_accuracy: 0.8904
# Epoch 13/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.2481 - accuracy: 0.8975 - val_loss: 0.2586 - val_accuracy: 0.8954
# Epoch 14/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.2426 - accuracy: 0.9017 - val_loss: 0.2545 - val_accuracy: 0.8981
# Epoch 15/20
# 163/163 [==============================] - 8s 48ms/step - loss: 0.2319 - accuracy: 0.9071 - val_loss: 0.2611 - val_accuracy: 0.8904
# Epoch 16/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2279 - accuracy: 0.9081 - val_loss: 0.2507 - val_accuracy: 0.8988
# Epoch 17/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2223 - accuracy: 0.9087 - val_loss: 0.2717 - val_accuracy: 0.8877
# Epoch 18/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2165 - accuracy: 0.9136 - val_loss: 0.2531 - val_accuracy: 0.8915
# Epoch 19/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2086 - accuracy: 0.9188 - val_loss: 0.2514 - val_accuracy: 0.9019
# Epoch 20/20
# 163/163 [==============================] - 8s 49ms/step - loss: 0.2071 - accuracy: 0.9185 - val_loss: 0.2497 - val_accuracy: 0.8981

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.89      0.90      0.90      1300
#      smiling       0.90      0.89      0.90      1300
#
#     accuracy                           0.90      2600
#    macro avg       0.90      0.90      0.90      2600
# weighted avg       0.90      0.90      0.90      2600

# %%
# train the network
# Dropout = 0.0
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 8s 45ms/step - loss: 0.5827 - accuracy: 0.6930 - val_loss: 0.4695 - val_accuracy: 0.7715
# Epoch 2/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.4407 - accuracy: 0.7965 - val_loss: 0.4076 - val_accuracy: 0.8162
# Epoch 3/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3990 - accuracy: 0.8227 - val_loss: 0.3745 - val_accuracy: 0.8304
# Epoch 4/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3679 - accuracy: 0.8414 - val_loss: 0.3457 - val_accuracy: 0.8446
# Epoch 5/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3477 - accuracy: 0.8510 - val_loss: 0.3483 - val_accuracy: 0.8465
# Epoch 6/20
# 163/163 [==============================] - 8s 49ms/step - loss: 0.3356 - accuracy: 0.8549 - val_loss: 0.3450 - val_accuracy: 0.8458
# Epoch 7/20
# 163/163 [==============================] - 8s 47ms/step - loss: 0.3205 - accuracy: 0.8644 - val_loss: 0.3113 - val_accuracy: 0.8681
# Epoch 8/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.3041 - accuracy: 0.8726 - val_loss: 0.3047 - val_accuracy: 0.8723
# Epoch 9/20
# 163/163 [==============================] - 8s 48ms/step - loss: 0.2977 - accuracy: 0.8748 - val_loss: 0.2928 - val_accuracy: 0.8788
# Epoch 10/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2909 - accuracy: 0.8765 - val_loss: 0.3332 - val_accuracy: 0.8585
# Epoch 11/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2834 - accuracy: 0.8845 - val_loss: 0.2992 - val_accuracy: 0.8758
# Epoch 12/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2750 - accuracy: 0.8866 - val_loss: 0.2884 - val_accuracy: 0.8815
# Epoch 13/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2727 - accuracy: 0.8886 - val_loss: 0.3011 - val_accuracy: 0.8773
# Epoch 14/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2582 - accuracy: 0.8950 - val_loss: 0.2839 - val_accuracy: 0.8819
# Epoch 15/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2554 - accuracy: 0.8951 - val_loss: 0.2892 - val_accuracy: 0.8796
# Epoch 16/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2476 - accuracy: 0.8984 - val_loss: 0.2967 - val_accuracy: 0.8777
# Epoch 17/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2459 - accuracy: 0.8996 - val_loss: 0.2801 - val_accuracy: 0.8815
# Epoch 18/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2362 - accuracy: 0.9049 - val_loss: 0.2847 - val_accuracy: 0.8831
# Epoch 19/20
# 163/163 [==============================] - 8s 51ms/step - loss: 0.2351 - accuracy: 0.9039 - val_loss: 0.2838 - val_accuracy: 0.8838 accuracy
# Epoch 20/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2235 - accuracy: 0.9093 - val_loss: 0.2782 - val_accuracy: 0.8869

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.90      0.87      0.89      1300
#      smiling       0.88      0.90      0.89      1300
#
#     accuracy                           0.89      2600
#    macro avg       0.89      0.89      0.89      2600
# weighted avg       0.89      0.89      0.89      2600

# %%
# train the network
# Dropout = 0.4
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 9s 49ms/step - loss: 0.5935 - accuracy: 0.6812 - val_loss: 0.4828 - val_accuracy: 0.7665
# Epoch 2/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.4686 - accuracy: 0.7857 - val_loss: 0.4353 - val_accuracy: 0.7992
# Epoch 3/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.4387 - accuracy: 0.7987 - val_loss: 0.4092 - val_accuracy: 0.8165
# Epoch 4/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.4074 - accuracy: 0.8169 - val_loss: 0.3916 - val_accuracy: 0.8123
# Epoch 5/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3827 - accuracy: 0.8299 - val_loss: 0.3826 - val_accuracy: 0.8254
# Epoch 6/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3653 - accuracy: 0.8392 - val_loss: 0.3384 - val_accuracy: 0.8527
# Epoch 7/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3457 - accuracy: 0.8504 - val_loss: 0.3259 - val_accuracy: 0.8592
# Epoch 8/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3303 - accuracy: 0.8565 - val_loss: 0.3157 - val_accuracy: 0.8642
# Epoch 9/20
# 163/163 [==============================] - 8s 47ms/step - loss: 0.3188 - accuracy: 0.8647 - val_loss: 0.3093 - val_accuracy: 0.8696
# Epoch 10/20
# 163/163 [==============================] - 8s 51ms/step - loss: 0.3092 - accuracy: 0.8690 - val_loss: 0.3092 - val_accuracy: 0.8735
# Epoch 11/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2965 - accuracy: 0.8764 - val_loss: 0.3002 - val_accuracy: 0.8715
# Epoch 12/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2878 - accuracy: 0.8803 - val_loss: 0.3105 - val_accuracy: 0.8704
# Epoch 13/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2805 - accuracy: 0.8854 - val_loss: 0.2980 - val_accuracy: 0.8731
# Epoch 14/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2759 - accuracy: 0.8863 - val_loss: 0.2931 - val_accuracy: 0.8723
# Epoch 15/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2650 - accuracy: 0.8905 - val_loss: 0.2889 - val_accuracy: 0.8785
# Epoch 16/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2563 - accuracy: 0.8965 - val_loss: 0.2823 - val_accuracy: 0.8846
# Epoch 17/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2505 - accuracy: 0.8957 - val_loss: 0.2758 - val_accuracy: 0.8846
# Epoch 18/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2427 - accuracy: 0.9013 - val_loss: 0.2814 - val_accuracy: 0.8777
# Epoch 19/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2407 - accuracy: 0.8983 - val_loss: 0.2782 - val_accuracy: 0.8881
# Epoch 20/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2334 - accuracy: 0.9071 - val_loss: 0.2960 - val_accuracy: 0.8719

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.88      0.87      0.87      1300
#      smiling       0.87      0.88      0.87      1300
#
#     accuracy                           0.87      2600
#    macro avg       0.87      0.87      0.87      2600
# weighted avg       0.87      0.87      0.87      2600

# %%
# save the model to disk
model.save(output)
# Out:
# INFO:tensorflow:Assets written to: output\assets
