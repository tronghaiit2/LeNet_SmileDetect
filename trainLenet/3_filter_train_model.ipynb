# %%
data_set = "dataset/SMILEsmileD/SMILEs"
output = "output"
# initialize the list of data and labels
data = []
labels = []

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical
from pipeline.nn.conv import LeNet
from imutils import paths
from matplotlib import pyplot
import imutils 
import numpy as np
import argparse
import cv2
import os

# %%
# loop over the input images
for imagePath in sorted(list(paths.list_images(data_set))):
    # load the image, pre-process it, and store it in the data list
    #print(imagePath)
    image = cv2.imread(imagePath)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #image = imutils.resize(image, width=32)
    image = cv2.resize(image, (32,32), interpolation=cv2.INTER_AREA)
    image = img_to_array(image)
    data.append(image)

    # extract the class label from the image path and update the label list
    label = imagePath.split(os.path.sep)[-3]
    label = "smiling" if label == "positives" else "not_smiling"
    labels.append(label)

count = 0
count_neg = 0
for i in range(len(labels)):
    if labels[i] == "smiling":
        count += 1
    else:
        count_neg += 1

print(count)
print(count_neg)
# Out:
# 6500
# 6500

# %%
len(labels)
#labels
# Out:
# 13000

# %%
# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
labels
# Out:
# array(['not_smiling', 'not_smiling', 'not_smiling', ..., 'smiling',
#        'smiling', 'smiling'], dtype='<U11')

# %%
# convert the labels from integers to vectors
le = LabelEncoder().fit(labels)
labels = to_categorical(le.transform(labels), 2)

# account for skew in the labeled data
classTotals = labels.sum(axis=0)
classWeight = classTotals.max() / classTotals

# %%
classTotals
# Out:
# array([6500., 6500.], dtype=float32)

# %%
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.20, stratify=labels, random_state=42)

# %%
print(len(trainX), len(trainY), len(testX), len(testY))
# Out:
# 10400 10400 2600 2600

# %%
# initialize the model
print("[INFO] compiling model...")
model = LeNet.build(width=32, height=32, depth=1, classes=2)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# [INFO] compiling model...

# %%
# train the network
# 16 filter
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 8s 45ms/step - loss: 0.5687 - accuracy: 0.6948 - val_loss: 0.4681 - val_accuracy: 0.7862
# Epoch 2/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.4451 - accuracy: 0.7997 - val_loss: 0.4046 - val_accuracy: 0.8138
# Epoch 3/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3948 - accuracy: 0.8218 - val_loss: 0.3618 - val_accuracy: 0.8412
# Epoch 4/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3588 - accuracy: 0.8421 - val_loss: 0.3520 - val_accuracy: 0.8473
# Epoch 5/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3344 - accuracy: 0.8554 - val_loss: 0.3262 - val_accuracy: 0.8650
# Epoch 6/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3137 - accuracy: 0.8653 - val_loss: 0.3269 - val_accuracy: 0.8608
# Epoch 7/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.3047 - accuracy: 0.8689 - val_loss: 0.3032 - val_accuracy: 0.8681
# Epoch 8/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2898 - accuracy: 0.8799 - val_loss: 0.2798 - val_accuracy: 0.8827
# Epoch 9/20
# 163/163 [==============================] - 8s 47ms/step - loss: 0.2763 - accuracy: 0.8838 - val_loss: 0.2781 - val_accuracy: 0.8865
# Epoch 10/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2702 - accuracy: 0.8906 - val_loss: 0.2694 - val_accuracy: 0.8919
# Epoch 11/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2656 - accuracy: 0.8898 - val_loss: 0.2836 - val_accuracy: 0.8877
# Epoch 12/20
# 163/163 [==============================] - 8s 50ms/step - loss: 0.2536 - accuracy: 0.8956 - val_loss: 0.2683 - val_accuracy: 0.8904
# Epoch 13/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.2481 - accuracy: 0.8975 - val_loss: 0.2586 - val_accuracy: 0.8954
# Epoch 14/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.2426 - accuracy: 0.9017 - val_loss: 0.2545 - val_accuracy: 0.8981
# Epoch 15/20
# 163/163 [==============================] - 8s 48ms/step - loss: 0.2319 - accuracy: 0.9071 - val_loss: 0.2611 - val_accuracy: 0.8904
# Epoch 16/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2279 - accuracy: 0.9081 - val_loss: 0.2507 - val_accuracy: 0.8988
# Epoch 17/20
# 163/163 [==============================] - 7s 46ms/step - loss: 0.2223 - accuracy: 0.9087 - val_loss: 0.2717 - val_accuracy: 0.8877
# Epoch 18/20
# 163/163 [==============================] - 7s 45ms/step - loss: 0.2165 - accuracy: 0.9136 - val_loss: 0.2531 - val_accuracy: 0.8915
# Epoch 19/20
# 163/163 [==============================] - 8s 46ms/step - loss: 0.2086 - accuracy: 0.9188 - val_loss: 0.2514 - val_accuracy: 0.9019
# Epoch 20/20
# 163/163 [==============================] - 8s 49ms/step - loss: 0.2071 - accuracy: 0.9185 - val_loss: 0.2497 - val_accuracy: 0.8981

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.89      0.90      0.90      1300
#      smiling       0.90      0.89      0.90      1300
#
#     accuracy                           0.90      2600
#    macro avg       0.90      0.90      0.90      2600
# weighted avg       0.90      0.90      0.90      2600

# %%
# train the network
# 8 filter
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.6728 - accuracy: 0.5709 - val_loss: 0.5851 - val_accuracy: 0.7088
# Epoch 2/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.5031 - accuracy: 0.7614 - val_loss: 0.4723 - val_accuracy: 0.7692
# Epoch 3/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.4354 - accuracy: 0.8032 - val_loss: 0.4156 - val_accuracy: 0.8042
# Epoch 4/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.4094 - accuracy: 0.8182 - val_loss: 0.3890 - val_accuracy: 0.8262
# Epoch 5/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3836 - accuracy: 0.8319 - val_loss: 0.3805 - val_accuracy: 0.8269
# Epoch 6/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3628 - accuracy: 0.8428 - val_loss: 0.3687 - val_accuracy: 0.8265
# Epoch 7/20
# 163/163 [==============================] - 7s 44ms/step - loss: 0.3488 - accuracy: 0.8504 - val_loss: 0.3298 - val_accuracy: 0.8531
# Epoch 8/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3318 - accuracy: 0.8586 - val_loss: 0.3199 - val_accuracy: 0.8596
# Epoch 9/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3247 - accuracy: 0.8631 - val_loss: 0.3121 - val_accuracy: 0.8669
# Epoch 10/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3107 - accuracy: 0.8689 - val_loss: 0.3034 - val_accuracy: 0.8658
# Epoch 11/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.3041 - accuracy: 0.8721 - val_loss: 0.3074 - val_accuracy: 0.8708
# Epoch 12/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2964 - accuracy: 0.8764 - val_loss: 0.2918 - val_accuracy: 0.8746
# Epoch 13/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.2860 - accuracy: 0.8826 - val_loss: 0.3003 - val_accuracy: 0.8700
# Epoch 14/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2832 - accuracy: 0.8809 - val_loss: 0.2819 - val_accuracy: 0.8804
# Epoch 15/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.2740 - accuracy: 0.8888 - val_loss: 0.3091 - val_accuracy: 0.8715
# Epoch 16/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2669 - accuracy: 0.8902 - val_loss: 0.2700 - val_accuracy: 0.8854
# Epoch 17/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.2621 - accuracy: 0.8925 - val_loss: 0.2714 - val_accuracy: 0.8842
# Epoch 18/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2563 - accuracy: 0.8943 - val_loss: 0.2812 - val_accuracy: 0.8842
# Epoch 19/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2498 - accuracy: 0.8976 - val_loss: 0.2846 - val_accuracy: 0.8804
# Epoch 20/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2445 - accuracy: 0.8991 - val_loss: 0.2762 - val_accuracy: 0.8842

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.91      0.86      0.88      1300
#      smiling       0.86      0.91      0.89      1300
#
#     accuracy                           0.88      2600
#    macro avg       0.89      0.88      0.88      2600
# weighted avg       0.89      0.88      0.88      2600

# %%
# train the network
# 6 filter
print("[INFO] training network...")
H = model.fit(trainX, trainY, batch_size=64, epochs=20, validation_data=(testX, testY), verbose=1)
pyplot.plot(H.history['loss'], label='train')
pyplot.plot(H.history['val_loss'], label='test')
#pyplot.plot(H.history['accuracy'], label='acc')
#pyplot.plot(H.history['val_accuracy'], label='pre')
pyplot.legend()
pyplot.show()
# Out:
# [INFO] training network...
# Epoch 1/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.5949 - accuracy: 0.6667 - val_loss: 0.5018 - val_accuracy: 0.7538
# Epoch 2/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.4752 - accuracy: 0.7756 - val_loss: 0.4668 - val_accuracy: 0.7742
# Epoch 3/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.4371 - accuracy: 0.7973 - val_loss: 0.4176 - val_accuracy: 0.8004
# Epoch 4/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.4080 - accuracy: 0.8154 - val_loss: 0.3844 - val_accuracy: 0.8265
# Epoch 5/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3862 - accuracy: 0.8276 - val_loss: 0.3747 - val_accuracy: 0.8346
# Epoch 6/20
# 163/163 [==============================] - 6s 39ms/step - loss: 0.3698 - accuracy: 0.8351 - val_loss: 0.3551 - val_accuracy: 0.8450
# Epoch 7/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.3541 - accuracy: 0.8447 - val_loss: 0.3458 - val_accuracy: 0.8512
# Epoch 8/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.3438 - accuracy: 0.8510 - val_loss: 0.3314 - val_accuracy: 0.8581
# Epoch 9/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.3263 - accuracy: 0.8584 - val_loss: 0.3220 - val_accuracy: 0.8635
# Epoch 10/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.3172 - accuracy: 0.8636 - val_loss: 0.3129 - val_accuracy: 0.8631
# Epoch 11/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.3048 - accuracy: 0.8698 - val_loss: 0.3139 - val_accuracy: 0.8700
# Epoch 12/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2931 - accuracy: 0.8767 - val_loss: 0.3067 - val_accuracy: 0.8719
# Epoch 13/20
# 163/163 [==============================] - 6s 40ms/step - loss: 0.2868 - accuracy: 0.8808 - val_loss: 0.3029 - val_accuracy: 0.8746
# Epoch 14/20
# 163/163 [==============================] - 7s 41ms/step - loss: 0.2753 - accuracy: 0.8866 - val_loss: 0.3099 - val_accuracy: 0.8685
# Epoch 15/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2662 - accuracy: 0.8913 - val_loss: 0.3040 - val_accuracy: 0.8650
# Epoch 16/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2571 - accuracy: 0.8960 - val_loss: 0.2996 - val_accuracy: 0.8746
# Epoch 17/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2468 - accuracy: 0.8982 - val_loss: 0.2918 - val_accuracy: 0.8742
# Epoch 18/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2390 - accuracy: 0.9016 - val_loss: 0.3041 - val_accuracy: 0.8727
# Epoch 19/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2323 - accuracy: 0.9041 - val_loss: 0.2976 - val_accuracy: 0.8750
# Epoch 20/20
# 163/163 [==============================] - 7s 40ms/step - loss: 0.2292 - accuracy: 0.9040 - val_loss: 0.2964 - val_accuracy: 0.8762

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=le.classes_))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#  not_smiling       0.89      0.86      0.87      1300
#      smiling       0.86      0.89      0.88      1300
#
#     accuracy                           0.88      2600
#    macro avg       0.88      0.88      0.88      2600
# weighted avg       0.88      0.88      0.88      2600

# %%
# save the model to disk
model.save(output)
# Out:
# INFO:tensorflow:Assets written to: output\assets
